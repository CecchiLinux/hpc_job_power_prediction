# %%
import pandas as pd
import errno    
import os
import numpy as np
import math

'''
Author: Enrico Ceccolini
    unifica differenti intervalli di job
'''

datadir = "/datasets/eurora_data/db1/"

#infile_jobs_to_nodes = datadir + "job_nodes.csv"

suffix = "_5sec_"
### select an interval from
## 1 settings wholeData
#interval_comment_whole = "WholeData"

### select an interval from
## 2 settings Andrea
interval_comment = "Andrea"
start_time = pd.to_datetime('2014-03-31')
end_time = pd.to_datetime('2014-05-01')
#infile_jobs = datadir + "april_long_jobs.csv"

## 3 settings Alina
interval_comment = "Alina"
start_time = pd.to_datetime('2014-03-31')
end_time = pd.to_datetime('2014-11-01')

## 3 settings Alina
interval_comment_2 = "BeforeAlina"
start_time_2 = pd.to_datetime('2014-03-31')
end_time_2 = pd.to_datetime('2014-07-01')


infile_jobs = datadir + "CPUs/" + interval_comment + "/" + interval_comment + "_long_jobs_real_pow"
infile_jobs_2 = datadir + "CPUs/" + interval_comment_2 + "/" + interval_comment_2 + "_long_jobs_real_pow"

# %%
jobs = pd.read_csv(infile_jobs + ".csv", index_col=0)
print("There are {} long jobs in the {}'s interval".format(jobs.shape[0], interval_comment))

jobs_2 = pd.read_csv(infile_jobs_2 + ".csv", index_col=0)
print("There are {} long jobs in the {}'s interval".format(jobs_2.shape[0], interval_comment_2))
# Out:
# There are 237428 long jobs in the Alina's interval
# There are 100003 long jobs in the BeforeAlina's interval
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
frames = [jobs_2, jobs]
result = pd.concat(frames)
print("There are {} long jobs in the {}'s interval".format(result.shape[0], interval_comment))
# Out:
# There are 337431 long jobs in the Alina's interval

# %%
result.drop_duplicates(subset=['job_id_string'], keep='first', inplace=True)
print("There are {} long jobs in the {}'s interval".format(result.shape[0], interval_comment))
# Out:
# There are 336787 long jobs in the Alina's interval

# %%
result
# Out:
#          job_id_string      job_name     queue           start_time  \
# job_id
# 1       498458.node129      rth2e6t0  parallel  2014-03-31 00:30:02
# 2       498459.node129          CPMD  parallel  2014-03-31 00:36:51
# 3       498460.node129   7ribb-relax  parallel  2014-03-31 00:54:37
# 4       498461.node129    rth2e6t0DC  parallel  2014-03-31 01:00:01
# 5       498462.node129      rth2e6t0  parallel  2014-03-31 01:30:02
# 6       498463.node129      rth2e6t0  parallel  2014-03-31 02:30:02
# 7       498464.node129      rth2e6t0  parallel  2014-03-31 03:30:09
# 8       498465.node129          INIT   R472836  2014-03-31 04:00:17
# 9       498466.node129        LM_PRE   R472836  2014-03-31 04:00:17
# 10      498467.node129       LM7_OPE   R472836  2014-03-31 04:23:23
# 11      498468.node129   POSTPROCESS   R472836  2014-03-31 04:23:25
# 12      498469.node129          ARKI   R472836  2014-03-31 04:23:25
# 13      498470.node129     TRANSFER1   R472836  2014-03-31 04:23:26
# ...

# %%
outfile_jobs = datadir + "CPUs/" + interval_comment + "/" + interval_comment + "_long_jobs_real_pow"
result.to_csv(outfile_jobs + ".csv")
