# %%
#!/usr/bin/env python3

import pandas as pd
import errno    
import os, sys
import numpy as np

'''
Author: Enrico Ceccolini
'''

datadir = "/datasets/eurora_data/db1/"

# settings
#interval_comment = "Andrea"
start_time = pd.to_datetime('2014-03-31')
end_time = pd.to_datetime('2014-05-01')
#interval_comment = "Alina"
#start_time = pd.to_datetime('2014-09-30')
#end_time = pd.to_datetime('2014-11-01')
suffix = "_1min_"  
interval_comment = "WholeData"

infile_jobs = datadir + "CPUs/" + interval_comment + "/large_jobs_real_pow_final.csv"
large_jobs = pd.read_csv(infile_jobs, index_col=0)
print("There are {} jobs in the {}'s interval".format(large_jobs.shape[0], interval_comment))

infile_jobs_whole = datadir + "jobs.csv"
whole_jobs = pd.read_csv(infile_jobs_whole, index_col=0)
# Out:
# There are 64000 jobs in the WholeData's interval
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
large_jobs['job_name'] = ""
#interval_jobs

# %%
for index, row in large_jobs.iterrows():
    large_jobs.at[index, 'job_name'] = whole_jobs[whole_jobs['job_id_string'] == row['job_id_string']].iloc[0]['job_name']

# %%
large_jobs
# Out:
#         job_id_string       queue           start_time       run_start_time  \
# 0      498458.node129    parallel  2014-03-31 00:30:02  2014-03-31 00:30:02
# 1      498459.node129    parallel  2014-03-31 00:36:51  2014-03-31 00:36:51
# 2      498460.node129    parallel  2014-03-31 00:54:37  2014-03-31 00:54:38
# 3      498461.node129    parallel  2014-03-31 01:00:01  2014-03-31 01:00:02
# 4      498462.node129    parallel  2014-03-31 01:30:02  2014-03-31 01:30:02
# 5      498463.node129    parallel  2014-03-31 02:30:02  2014-03-31 02:30:02
# 6      498464.node129    parallel  2014-03-31 03:30:09  2014-03-31 03:30:09
# 7      498465.node129     R472836  2014-03-31 04:00:17  2014-03-31 04:00:17
# 8      498466.node129     R472836  2014-03-31 04:00:17  2014-03-31 04:00:18
# 9      498467.node129     R472836  2014-03-31 04:23:23  2014-03-31 04:23:30
# 10     498468.node129     R472836  2014-03-31 04:23:25  2014-03-31 04:23:25
# ...

# %%
# interval_jobs = interval_jobs.rename(index=str, columns={"runned_alone": "ran_alone"})

# %%
infile_jobs = datadir + "CPUs/" + interval_comment + "/large_jobs_real_pow_final.csv"
large_jobs.to_csv(infile_jobs)

# %%
#infile_jobs
# Out:
# '/datasets/eurora_data/db1/jobs.csv'
